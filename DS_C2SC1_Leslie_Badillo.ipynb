# %% [markdown]
# <a href="https://colab.research.google.com/github/labadilloj/TLG-DS-2025/blob/main/DS_C2SC1_Leslie_Badillo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Abrir el archivo e iterar sobre cada uno de los renglones.
#No olvides que el primer renglón no se debe considerar, ya que contiene los nombres de las columnas.
from os import read
data = open('casos_confirmados.csv', 'r')
next(data) #Para no hacer cálculos con encabezados
print(header_line)
# Out:
# ,State,Sex,Age,Date,Confirmed

# %%
#2. Por cada renglón, recupera la edad y el género del paciente.
for line in data:
  data=line.strip().split(',') #Para quitar espacios y separar por comas
  edad=data[3]
  genero=data[2]
  print(edad, genero) #Obtener edad y género por renglon
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 56 FEMENINO
# 38 FEMENINO
# 69 MASCULINO
# 31 MASCULINO
# 55 FEMENINO
# 40 MASCULINO
# 60 MASCULINO
# 67 FEMENINO
# 46 FEMENINO
# 40 MASCULINO
# 56 MASCULINO
# 42 FEMENINO
# 77 FEMENINO
# 69 MASCULINO
# 23 FEMENINO
# 50 FEMENINO
# 21 FEMENINO
# 54 FEMENINO
# 32 MASCULINO
# 40 MASCULINO
# 40 MASCULINO
# 57 FEMENINO
# 64 MASCULINO
# 35 MASCULINO
# 31 FEMENINO
# 85 MASCULINO
# 87 FEMENINO
# 41 FEMENINO
# 36 MASCULINO
# 53 FEMENINO
# 62 FEMENINO
# 62 MASCULINO
# 6 MASCULINO
# 52 MASCULINO
# 47 FEMENINO
# 45 MASCULINO
# 61 FEMENINO
# 61 MASCULINO
# 24 MASCULINO
# 25 FEMENINO
# 75 MASCULINO
# 26 MASCULINO
# 71 MASCULINO
# 24 FEMENINO
# 0 FEMENINO
# 45 FEMENINO
# 9 MASCULINO
# 25 FEMENINO
# 60 FEMENINO
# 36 MASCULINO
# 46 MASCULINO
# 44 FEMENINO
# 44 FEMENINO
# 57 FEMENINO
# 52 MASCULINO
# 29 MASCULINO
# 55 FEMENINO
# 24 FEMENINO
# 23 FEMENINO
# 40 MASCULINO
# 29 FEMENINO
# 53 FEMENINO
# 37 MASCULINO
# 49 FEMENINO
# ...

# %%
#3.Conocer la edad promedio de los participantes y si hay más hombres o mujeres contagiados.
contagiados=0
mujeres=0
hombres=0

try:
  edad=int(edad)
  edad_total += edad
  print(edad_total)
  for i in contagiados:
  contagiados=contagiados + 1
  print(contagiados)

  edad_promedio=edad_total/contagiados
  print(edad_promedio)

except ValueError:
  pass
# Out:
#   File "/tmp/ipython-input-280-1181900497.py", line 11
#     contagiados=contagiados + 1
#     ^
# IndentationError: expected an indented block after 'for' statement on line 10

# %%
if genero== 'FEMENINO':
  mujeres=mujeres+1
else:
  hombres=hombres+1


#4.Imprime la respuesta a las siguientes preguntas:
##¿Cuál es la edad promedio de los pacientes?
print('La edad promedio de los pacientes es de:'edad_promedio)
##¿Hay más hombres o mujeres contagiados?
 if mujeres>hombres:
    print('Son más mujeres que hombres con un total de:', mujeres)
  else:
    print("Son más hombres que mujeres con un total de:", hombres)

data.close()
